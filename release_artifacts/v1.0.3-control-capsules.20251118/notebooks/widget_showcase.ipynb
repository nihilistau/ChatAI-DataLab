# %% [markdown]
# # DataLab Widget Showcase
# This notebook demonstrates the freshly minted widget + panel library.

# %%
from kitchen.widgets import build_library
library = build_library()
{"telemetry": len(library.telemetry), "control": len(library.control), "narrative": len(library.narrative)}
# Out:
# {'telemetry': 5, 'control': 5, 'narrative': 5}

# %%
for panel in library.panels:
    print(panel.title)
    print(panel.render_markdown())
    print('-' * 40)
# Out:
# Ops Flight
# ## Panel · Ops Flight
# > Mix telemetry + macros
#
# ### Latency Orbit
# - category: telemetry
# - value: 118 ms · trend avg 73.7
# - intent: info
# p95 ms for inference pods
#
# ### Command Deck
# - category: control
# - value: restart api
# - intent: danger
# Primary macro used by ops lead
#
# ### Guardrail Health
# - category: telemetry
# - value: 86% pass · trend avg 78.6
# - intent: success
# Live pass rate
#
#
# ----------------------------------------
# Notebook Flight
# ## Panel · Notebook Flight
# > Notebook success + control
#
# ### RU Budget
# - category: telemetry
# - value: 72% · trend avg 66.4
# - intent: warning
# Guardrail for Cosmos consumption
#
# ### Notebook Scale
# - category: control
# - value: scale notebooks
# - intent: success
# Auto-scaling macro
#
# ### Prompt Rhythm Insight
# - category: narrative
# - value: +18% quality
# - intent: success
# Cadence vs quality story
#
#
# ----------------------------------------
# Signal Canvas
# ## Panel · Signal Canvas
# > Narratives with live data
#
# ### Win Log
# - category: narrative
# - value: 3 wins
# - intent: success
# Recent achievements
#
# ### Token Drift
# - category: telemetry
# - value: 1.3k avg · trend avg 57.8
# - intent: info
# Rolling token consumption for prompts
#
#
# ----------------------------------------
# Guardrail Sentinel
# ## Panel · Guardrail Sentinel
# > Audit-friendly view
#
# ### Guardrail Health
# - category: telemetry
# - value: 86% pass · trend avg 78.6
# - intent: success
# Live pass rate
#
# ### Guardrail Audit
# - category: control
# - value: launch audit
# - intent: warning
# Runs compliance notebook
#
# ### Anomaly Alerts
# - category: telemetry
# - value: 7 active · trend avg 3.4
# - intent: danger
# Unacknowledged anomalies across tenants
#
#
# ----------------------------------------
# Insight Anthology
# ## Panel · Insight Anthology
# > Story-driven console
#
# ### Prompt Rhythm Insight
# - category: narrative
# - value: +18% quality
# - intent: success
# Cadence vs quality story
#
# ### Design Tenets
# - category: narrative
# - value: 3 pillars
# - intent: info
# Guiding design rules
#
# ### Sync Telemetry
# - category: control
# - value: sync telemetry
# - intent: info
# Refreshes search + ops deck
#
#
# ----------------------------------------
