# %% [markdown]
# # Onboarding Recipe
# Welcome to Kitchen! This Recipe will walk you through your first steps.

# %% [markdown]
# ## Step 1: Run Your First Cell

# %%
print('Hello, new Kitchen chef!')

# %% [markdown]
# ## Step 2: Chain Outputs

# %%
x = 7
print('x =', x)

# %%
y = x * 3
print('y =', y)

# %% [markdown]
# ## Step 3: Extend Kitchen

# %%
def custom_greeting():
    print('You can extend Kitchen with your own Recipes!')
custom_greeting()
