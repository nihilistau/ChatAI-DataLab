# %% [markdown]
# # Good Luck Notebook
#
# This notebook prints good luck messages and motivational content to inspire you!

# %%
# Section 1: Print a Good Luck Message
print("Good luck! Wishing you success in all your projects!")

# %% [markdown]
# ## Display a Random Motivational Quote

# %%
# Section 2: Display a Random Motivational Quote
import random
quotes = [
    "Success is not final, failure is not fatal: It is the courage to continue that counts.",
    "Believe you can and you're halfway there.",
    "The only way to do great work is to love what you do.",
    "Don't watch the clock; do what it does. Keep going.",
    "The future depends on what you do today."
]
print("Motivational Quote:", random.choice(quotes))

# %% [markdown]
# ## Generate a Good Luck Emoji

# %%
# Section 3: Generate a Good Luck Emoji
emojis = ['🍀', '🧧', '🎉', '🌟', '🤞', '🦄', '🐞']
print("Good Luck Emoji:", random.choice(emojis))
